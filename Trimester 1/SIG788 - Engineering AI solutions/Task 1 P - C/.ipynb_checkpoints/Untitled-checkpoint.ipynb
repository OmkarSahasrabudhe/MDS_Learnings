# %%
import pandas as pd

# %%
# # Read the ARFF file
# data = arff.loadarff('Chronic_Kidney_Disease/chronic_kidney_disease.arff')

# data = []
# with open('Chronic_Kidney_Disease/chronic_kidney_disease_full.arff', "r") as f:
#     for line in f:
#         line = line.replace('\n', '')
#         data.append(line.split(','))

# # Convert the data to a Pandas DataFrame
# df = pd.DataFrame(data)

# # Print the data
# print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/bf/l8qs24p96z39_pdl8jt8j5bh0000gn/T/ipykernel_5389/751710585.py in <module>
#       1 # Read the ARFF file
# ----> 2 data = arff.loadarff('Chronic_Kidney_Disease/chronic_kidney_disease.arff')
#       3
#       4 # data = []
#       5 # with open('Chronic_Kidney_Disease/chronic_kidney_disease_full.arff', "r") as f:
#
# /usr/local/lib/python3.9/site-packages/scipy/io/arff/arffread.py in loadarff(f)
#     800         ofile = open(f, 'rt')
#     801     try:
# --> 802         return _loadarff(ofile)
#     803     finally:
#     804         if ofile is not f:  # only close what we opened
#
# /usr/local/lib/python3.9/site-packages/scipy/io/arff/arffread.py in _loadarff(ofile)
#     865             yield tuple([attr[i].parse_data(row[i]) for i in elems])
#     866
# --> 867     a = list(generator(ofile))
#     868     # No error should happen here: it is a bug otherwise
#     869     data = np.array(a, [(a.name, a.dtype) for a in attr])
#
# /usr/local/lib/python3.9/site-packages/scipy/io/arff/arffread.py in generator(row_iter, delim)
#     863             row, dialect = split_data_line(raw, dialect)
#     864
# --> 865             yield tuple([attr[i].parse_data(row[i]) for i in elems])
#     866
#     867     a = list(generator(ofile))
#
# /usr/local/lib/python3.9/site-packages/scipy/io/arff/arffread.py in <listcomp>(.0)
#     863             row, dialect = split_data_line(raw, dialect)
#     864
# --> 865             yield tuple([attr[i].parse_data(row[i]) for i in elems])
#     866
#     867     a = list(generator(ofile))
#
# /usr/local/lib/python3.9/site-packages/scipy/io/arff/arffread.py in parse_data(self, data_str)
#     156             return data_str
#     157         else:
# --> 158             raise ValueError("%s value not in %s" % (str(data_str),
#     159                                                      str(self.values)))
#     160
#
# ValueError:  yes value not in ('yes', 'no')

# %%
data = []
with open('Chronic_Kidney_Disease/chronic_kidney_disease.arff', "r") as f:
    for line in f:
        line = line.replace('\n', '')
        data.append(line.split(','))

"""
age		-	age	
bp		-	blood pressure
sg		-	specific gravity
al		-   	albumin
su		-	sugar
rbc		-	red blood cells
pc		-	pus cell
pcc		-	pus cell clumps
ba		-	bacteria
bgr		-	blood glucose random
bu		-	blood urea
sc		-	serum creatinine
sod		-	sodium
pot		-	potassium
hemo		-	hemoglobin
pcv		-	packed cell volume
wc		-	white blood cell count
rc		-	red blood cell count
htn		-	hypertension
dm		-	diabetes mellitus
cad		-	coronary artery disease
appet		-	appetite
pe		-	pedal edema
ane		-	anemia
class		-	class	
"""
        
# Convert the data to a Pandas DataFrame
names = ['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba',
         'bgr', 'bu',  'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc',
         'rc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'class', 'no_name']

df = pd.DataFrame(data[145:], columns=names)

df
# Out:
#     age    bp     sg    al    su     rbc        pc         pcc          ba  \
# 0    48    80  1.020     1     0       ?    normal  notpresent  notpresent
# 1     7    50  1.020     4     0       ?    normal  notpresent  notpresent
# 2    62    80  1.010     2     3  normal    normal  notpresent  notpresent
# 3    48    70  1.005     4     0  normal  abnormal     present  notpresent
# 4    51    80  1.010     2     0  normal    normal  notpresent  notpresent
# ..   ..   ...    ...   ...   ...     ...       ...         ...         ...
# 397  12    80  1.020     0     0  normal    normal  notpresent  notpresent
# 398  17    60  1.025     0     0  normal    normal  notpresent  notpresent
# 399  58    80  1.025     0     0  normal    normal  notpresent  notpresent
# 400      None   None  None  None    None      None        None        None
# 401      None   None  None  None    None      None        None        None
#
#       bgr  ...    wc    rc   htn    dm   cad appet    pe   ane   class no_name
# 0     121  ...  7800   5.2   yes   yes    no  good    no    no     ckd    None
# 1       ?  ...  6000     ?    no    no    no  good    no    no     ckd    None
# 2     423  ...  7500     ?    no   yes    no  poor    no   yes     ckd    None
# 3     117  ...  6700   3.9   yes    no    no  poor   yes   yes     ckd    None
# 4     106  ...  7300   4.6    no    no    no  good    no    no     ckd    None
# ..    ...  ...   ...   ...   ...   ...   ...   ...   ...   ...     ...     ...
# 397   100  ...  6600   5.4    no    no    no  good    no    no  notckd    None
# 398   114  ...  7200   5.9    no    no    no  good    no    no  notckd    None
# 399   131  ...  6800   6.1    no    no    no  good    no    no  notckd    None
# 400  None  ...  None  None  None  None  None  None  None  None    None    None
# 401  None  ...  None  None  None  None  None  None  None  None    None    None
#
# [402 rows x 26 columns]
